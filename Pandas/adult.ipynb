# %%
import pandas as pd
df = pd.read_csv('adult_data.csv')
print(df['race'].value_counts())
# Out:
# White                 27816
# Black                  3124
# Asian-Pac-Islander     1039
# Amer-Indian-Eskimo      311
# Other                   271
# Name: race, dtype: int64

# %%
df.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'education-num',
#        'marital-status', 'occupation', 'relationship', 'race', 'sex',
#        'capital-gain', 'capital-loss', 'hours-per-week', 'native-country',
#        'salary'],
#       dtype='object')

# %%
df.head(7)
# Out:
#    age         workclass  fnlwgt  education  education-num  \
# 0   39         State-gov   77516  Bachelors             13
# 1   50  Self-emp-not-inc   83311  Bachelors             13
# 2   38           Private  215646    HS-grad              9
# 3   53           Private  234721       11th              7
# 4   28           Private  338409  Bachelors             13
# 5   37           Private  284582    Masters             14
# 6   49           Private  160187        9th              5
#
#           marital-status         occupation   relationship   race     sex  \
# 0          Never-married       Adm-clerical  Not-in-family  White    Male
# 1     Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2               Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3     Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4     Married-civ-spouse     Prof-specialty           Wife  Black  Female
# ...

# %%
sex = df[df['sex'].str.contains('Male')]
print(sex['age'].mean())
# Out:
# 39.43354749885268

# %%
print(df.query('age>=89')[['age', 'education', 'sex']])
# Out:
#        age     education     sex
# 222     90       HS-grad    Male
# 1040    90       HS-grad  Female
# 1935    90     Bachelors    Male
# 2303    90  Some-college    Male
# 2891    90  Some-college  Female
# 4070    90          11th    Male
# 4109    90     Bachelors  Female
# 5104    90  Some-college    Male
# 5272    90           9th  Female
# 5370    90       Masters    Male
# 5406    90       Masters    Male
# 6232    90     Bachelors    Male
# 6624    90          11th    Male
# 8806    90   Prof-school    Male
# 8963    90       HS-grad  Female
# 8973    90     Bachelors    Male
# 10210   90  Some-college    Male
# 10545   90       HS-grad    Male
# 11512   90       HS-grad  Female
# 11731   90       HS-grad    Male
# 11996   90     Bachelors    Male
# 12451   90  Some-college    Male
# 12975   90          10th    Male
# 14159   90    Assoc-acdm    Male
# 15356   90       HS-grad    Male
# 15892   90     Bachelors  Female
# 18277   90     Bachelors    Male
# ...

# %%
education = df['education'].value_counts()
total = df['education'].count()
porcentaje = (5355 / total) * 100
print(porcentaje)
# Out:
# 16.44605509658794

# %%
punto = df[['age', 'education', 'capital-gain']]
punto
# Out:
#        age   education  capital-gain
# 0       39   Bachelors          2174
# 1       50   Bachelors             0
# 2       38     HS-grad             0
# 3       53        11th             0
# 4       28   Bachelors             0
# ...    ...         ...           ...
# 32556   27  Assoc-acdm             0
# 32557   40     HS-grad             0
# 32558   58     HS-grad             0
# 32559   22     HS-grad             0
# 32560   52     HS-grad         15024
#
# [32561 rows x 3 columns]

# %%
punto = punto[(punto['education'] == 'Bachelors') & (punto['capital-gain'] > 50000)]
punto
# Out:
#        age  education  capital-gain
# 1528    52  Bachelors         99999
# 1682    43  Bachelors         99999
# 1765    49  Bachelors         99999
# 2319    65  Bachelors         99999
# 6035    78  Bachelors         99999
# 7090    41  Bachelors         99999
# 7347    46  Bachelors         99999
# 8740    30  Bachelors         99999
# 9184    32  Bachelors         99999
# 9228    46  Bachelors         99999
# 10366   32  Bachelors         99999
# 10771   46  Bachelors         99999
# 11976   30  Bachelors         99999
# 13422   53  Bachelors         99999
# 13499   50  Bachelors         99999
# 14827   33  Bachelors         99999
# 15100   62  Bachelors         99999
# 15604   50  Bachelors         99999
# 16174   42  Bachelors         99999
# 18315   42  Bachelors         99999
# 19084   52  Bachelors         99999
# 19133   69  Bachelors         99999
# 19807   48  Bachelors         99999
# 19900   55  Bachelors         99999
# 21489   58  Bachelors         99999
# ...
