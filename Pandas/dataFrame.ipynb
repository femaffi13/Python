# %% [markdown]
# # Pandas - Data Frames

# %% [markdown]
# DataFrames con diccionarios:

# %%
import pandas as pd
import numpy as np

data = {
    'state': ['Ohio', 'Ohio', 'Ohio', 'Nevada', 'Nevada', 'Nevada'],
    'year': [2000, 2001, 2002, 2001, 2002, 2003],
    'pop': [1.5, 1.7, 3.6, 2.4, 2.9, 3.2]
}

df = pd.DataFrame(data)
df
# Out:
#     state  year  pop
# 0    Ohio  2000  1.5
# 1    Ohio  2001  1.7
# 2    Ohio  2002  3.6
# 3  Nevada  2001  2.4
# 4  Nevada  2002  2.9
# 5  Nevada  2003  3.2

# %% [markdown]
# Modificar el orden de las columnas:

# %%
pd.DataFrame(data, columns = ['year', 'state', 'pop'])
# Out:
#    year   state  pop
# 0  2000    Ohio  1.5
# 1  2001    Ohio  1.7
# 2  2002    Ohio  3.6
# 3  2001  Nevada  2.4
# 4  2002  Nevada  2.9
# 5  2003  Nevada  3.2

# %% [markdown]
# ## Análisis preliminar de datos:

# %%
df = pd.read_csv('adult_data.csv')
df.shape  # Ver la cantidad de filas y columnas
# Out:
# (32561, 15)

# %%
df.head(3) #Visualizar los primeros 3 registros
#df.tail(3) --> Ver los último 3 registros
# Out:
#    age         workclass  fnlwgt  education  education-num  \
# 0   39         State-gov   77516  Bachelors             13
# 1   50  Self-emp-not-inc   83311  Bachelors             13
# 2   38           Private  215646    HS-grad              9
#
#        marital-status         occupation   relationship   race   sex  \
# 0       Never-married       Adm-clerical  Not-in-family  White  Male
# 1  Married-civ-spouse    Exec-managerial        Husband  White  Male
# 2            Divorced  Handlers-cleaners  Not-in-family  White  Male
#
#    capital-gain  capital-loss  hours-per-week native-country salary
# 0          2174             0              40  United-States  <=50K
# 1             0             0              13  United-States  <=50K
# 2             0             0              40  United-States  <=50K

# %%
df.dtypes #Columnas con el tipo de dato
# Out:
# age                int64
# workclass         object
# fnlwgt             int64
# education         object
# education-num      int64
# marital-status    object
# occupation        object
# relationship      object
# race              object
# sex               object
# capital-gain       int64
# capital-loss       int64
# hours-per-week     int64
# native-country    object
# salary            object
# dtype: object

# %%
df1 = df[['age', 'education', 'occupation', 'sex', 'salary']] #DF con las columnas elegidas
df1.head(5)
# Out:
#    age  education         occupation     sex salary
# 0   39  Bachelors       Adm-clerical    Male  <=50K
# 1   50  Bachelors    Exec-managerial    Male  <=50K
# 2   38    HS-grad  Handlers-cleaners    Male  <=50K
# 3   53       11th  Handlers-cleaners    Male  <=50K
# 4   28  Bachelors     Prof-specialty  Female  <=50K

# %% [markdown]
# Trabajar con datos faltantes:

# %%
dfTitanic = pd.read_csv('titanic.csv')
dfTitanic.head(15)
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
# 5             6         0       3
# 6             7         0       1
# 7             8         0       3
# 8             9         1       3
# 9            10         1       2
# 10           11         1       3
# 11           12         1       1
# 12           13         0       3
# 13           14         0       3
# 14           15         0       3
#
#                                                  Name     Sex   Age  SibSp  \
# 0                             Braund, Mr. Owen Harris    male  22.0      1
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                              Heikkinen, Miss. Laina  female  26.0      0
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# ...

# %%
dfTitanic.describe() #Estadística por cada columnna. Medidas de tendencia central y medidas de dispersión
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
dfTitanic.shape
# Out:
# (891, 12)

# %%
dfTitanic.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %% [markdown]
# Eliminar filas con NaN:

# %%
#titanic1 = dfTitanic.dropna(axis = 0, how = 'all') --> Elimina filas que posean NaN en TODAS sus columnas
titanic1 = dfTitanic.dropna(axis = 0, how = 'any') #Elimina filas que posean AL MENOS un NaN
titanic1.shape
# Out:
# (183, 12)

# %% [markdown]
# Rellenar datos NaN:

# %% [markdown]
# Contar la cantidad de los valores faltantes de una columna:

# %%
pd.isnull(dfTitanic['Age']).values.ravel().sum()
# Out:
# 177

# %% [markdown]
# Rellenar con el promedio de todas las edades:

# %%
col = dfTitanic['Age'].fillna(dfTitanic['Age'].mean())
col.head(6) #En el 6 registro se ve el promedio de las edades
# Out:
# 0    22.000000
# 1    38.000000
# 2    26.000000
# 3    35.000000
# 4    35.000000
# 5    29.699118
# Name: Age, dtype: float64

# %% [markdown]
# Agregar una nueva columna con los datos de col

# %%
dfTitanic['NewAge'] = col 
dfTitanic.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked', 'NewAge'],
#       dtype='object')

# %% [markdown]
# # One Hot Encoding
# Los modelos de Machine Learning necesitan procesar valores numéricos. En ciertos casos vamos a realizar análisis en las que existen variables categóricas (País, Sexo, Ciudad, etc.)
# Esta técnica convierte estas variables categóricas en variables numéricas

# %%
titanic1.head(3)
# Out:
#    PassengerId  Survived  Pclass  \
# 1            2         1       1
# 3            4         1       1
# 6            7         0       1
#
#                                                 Name     Sex   Age  SibSp  \
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                            McCarthy, Mr. Timothy J    male  54.0      0
#
#    Parch    Ticket     Fare Cabin Embarked
# 1      0  PC 17599  71.2833   C85        C
# 3      0    113803  53.1000  C123        S
# 6      0     17463  51.8625   E46        S

# %%
titanic1 = titanic1[['PassengerId', 'Name', 'Sex', 'Age']]
titanic1.head(3)
# Out:
#    PassengerId                                               Name     Sex  \
# 1            2  Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 3            4       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 6            7                            McCarthy, Mr. Timothy J    male
#
#     Age
# 1  38.0
# 3  35.0
# 6  54.0

# %%
dummy_sex = pd.get_dummies(titanic1['Sex'], prefix = 'sex')
dummy_sex.head(3)
# Out:
#    sex_female  sex_male
# 1           1         0
# 3           1         0
# 6           0         1

# %%
titanic1 = titanic1.drop(['Sex'], axis = 1)
titanic2 = pd.concat([titanic1, dummy_sex], axis = 1)
titanic2.head(3)
# Out:
#    PassengerId                                               Name   Age  \
# 1            2  Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0
# 3            4       Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0
# 6            7                            McCarthy, Mr. Timothy J  54.0
#
#    sex_female  sex_male
# 1           1         0
# 3           1         0
# 6           0         1

# %%
titanic2.shape
# Out:
# (183, 5)

# %%
def createDummies(df, varname):
    dummy = pd.get_dummies(df[varname], prefix=varname)
    df = df.drop(varname, axis=1)
    df = pd.concat([df, dummy], axis=1)
    return df

#createDummies(dataframe, 'columna') al dataframe le elimina columna y realiza un one hot encoding
